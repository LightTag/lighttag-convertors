# %% [markdown]
# # Converting LightTag to ADM

# %% [markdown]
# First install type typing_extensions
# ```bash
# pip install -r requirements.txt
# ```

# %%
import json
from lighttag_to_adm import save_lighttag_job_to_adm
#Load your LightTag data
data = json.load(open('/tmp/mixed_sample1_annotations.json'))

# %%
save_lighttag_job_to_adm(data,
                         out_path="/tmp/example", #Where to save it
                         allow_overwrite=False, #Allow overwriting a job
                         reviewed_only=False # Only use reviewed annotations
                        )
# Out:
# /home/tal/dev/lighttag/scratch/basis/lighttag_to_adm/conflict_resolver.py:48: UserWarning: Conflicts detected in example af085bb0-b27d-4be3-a1cd-009b987caac3.
# ...

# %%
import os
os.listdir('/tmp/example/') #The outpath will have a subdirectory with the jobname
# Out:
# ['mixed-sample1']

# %%
os.listdir('/tmp/example/mixed-sample1/')[:10] # IT will have ADMs
# Out:
# ['a_d1d8236b-7732-4db1-957e-2c085c99d490.adm.json',
#  'a_8b1b7a7f-a3fe-42a3-afe8-2bd9bce205d9.adm.json',
#  'a_5178f8be-c61c-4622-bb17-f917978cf7d3.adm.json',
#  'a_f28acf79-e01a-4d9f-af68-a1314d74cfbb.adm.json',
#  'a_477dae8b-0433-4dfd-a36a-004fadeed3be.adm.json',
#  'a_bb343aeb-5616-457c-9c40-e75884b980e3.adm.json',
#  'a_aa2db074-7a0d-426f-91e9-30ff2538f4c5.adm.json',
#  'a_07c6ab2e-fcf7-47ea-b49f-fb80afe8f223.adm.json',
#  'a_add8c108-03b0-4b9f-96c0-911b0e60d8e5.adm.json',
#  'a_828af6e7-5b62-443b-b901-be39f005a2b1.adm.json']

# %%
import pprint
pprint.pprint(json.load(open('/tmp/example/mixed-sample1//a_005badb1-5999-4ea5-a73c-de1c9d57056f.adm.json')))
# Out:
# {'attributes': {'entities': {'itemType': 'itemType',
#                              'items': [{'mentions': [{'endOffset': 4,
#                                                       'normalized': 'WFM',
#                                                       'startOffset': 1}],
#                                         'type': 'Ticker'}],
#                              'type': 'list'}},
#  'data': '$WFM what a monthly chart, wow',
#  'documentMetadata': {'lighttag_example_id': '005badb1-5999-4ea5-a73c-de1c9d57056f',
#                       'symbols': '$WFM',
#                       'user_name': 'Tim Parker'},
#  'version': '1.1.0'}

# %%
import json
from lighttag_to_adm import save_lighttag_job_to_adm


data = json.load(open('/tmp/mixed_sample1_annotations.json'))


save_lighttag_job_to_adm(data,
                         out_path="./out", #Where to save it
                         allow_overwrite=False, #Allow overwriting a job
                         reviewed_only=False # Only use reviewed annotations
                        )


print("debug me")
# Out:
# debug me
